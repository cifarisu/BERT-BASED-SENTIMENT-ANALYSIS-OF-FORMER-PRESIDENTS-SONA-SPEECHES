# %% [markdown]
# <a href="https://colab.research.google.com/github/cifcs2/Sentiment-Analysis-of-Former-Presidents-SONA-using-NLP/blob/main/DataCleaning2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Web scraping, pickle imports
import requests
from bs4 import BeautifulSoup
import pickle

# Scrapes transcript data from scrapsfromtheloft.com
def url_to_transcript(url):
    page = requests.get(url).text
    soup = BeautifulSoup(page, "lxml")
    text = [p.text for p in soup.find(class_="entry-content").find_all('p')]
    print(url)
    return text

# URLs of transcripts in scope
urls = ['https://www.officialgazette.gov.ph/1998/07/27/joseph-ejercito-estrada-first-state-of-the-nation-address-july-27-1998/',
        'https://www.officialgazette.gov.ph/2000/07/24/joseph-ejercito-estrada-third-state-of-the-nation-address-july-24-2000/',
        'http://www.officialgazette.gov.ph/2001/07/23/gloria-macapagal-arroyo-first-state-of-the-nation-address-july-23-2001/',
        'http://www.officialgazette.gov.ph/2002/07/22/gloria-macapagal-arroyo-second-state-of-the-nation-address-july-22-2002/',
        'http://www.officialgazette.gov.ph/2003/07/28/gloria-macapagal-arroyo-third-state-of-the-nation-address-july-28-2003/',
        'http://www.officialgazette.gov.ph/2004/07/26/gloria-macapagal-arroyo-fourth-state-of-the-nation-address-july-26-2004/',
        'http://www.officialgazette.gov.ph/2005/07/25/gloria-macapagal-arroyo-fifth-state-of-the-nation-address-july-25-2005/',
        'http://www.officialgazette.gov.ph/2006/07/24/gloria-macapagal-arroyo-sixth-state-of-the-nation-address-july-24-2006/',
        'http://www.officialgazette.gov.ph/2007/07/23/gloria-macapagal-arroyo-seventh-state-of-the-nation-address-july-23-2007/',
        'http://www.officialgazette.gov.ph/2008/07/28/gloria-macapagal-arroyo-eighth-state-of-the-nation-address-july-28-2008/',
        'http://www.officialgazette.gov.ph/2009/07/27/gloria-macapagal-arroyo-ninth-state-of-the-nation-address-july-27-2009/',
        'https://www.officialgazette.gov.ph/2012/07/23/english-translation-benigno-s-aquino-iii-third-state-of-the-nation-address-july-23-2012/',
        'https://www.officialgazette.gov.ph/2013/07/22/english-benigno-s-aquino-iii-fourth-state-of-the-nation-address-july-22-2013/',
        'https://www.officialgazette.gov.ph/2014/07/28/english-benigno-s-aquino-iii-fifth-state-of-the-nation-address-july-28-2014/',
        'https://www.officialgazette.gov.ph/2015/07/27/english-president-aquino-sixth-sona/',
        'https://www.officialgazette.gov.ph/2016/07/25/rodrigo-roa-duterte-first-state-of-the-nation-address-july-25-2016/',
        'https://www.officialgazette.gov.ph/2017/07/24/rodrigo-roa-duterte-second-state-of-the-nation-address-july-24-2017/',
        'https://www.officialgazette.gov.ph/2018/07/23/rodrigo-roa-duterte-third-state-of-the-nation-address-july-23-2018/',
        'https://www.officialgazette.gov.ph/2019/07/22/rodrigo-roa-duterte-fourth-state-of-the-nation-address-july-22-2019/',
        'https://www.officialgazette.gov.ph/2020/07/27/rodrigo-roa-duterte-fifth-state-of-the-nation-address-july-27-2020/',
        'https://www.officialgazette.gov.ph/2021/07/26/rodrigo-roa-duterte-sixth-state-of-the-nation-address-july-26-2021/']       

# President names
presidents = ['Estrada-1998', 'Estrada-2000', 'Arroyo-2001', 'Arroyo-2002', 'Arroyo-2003', 'Arroyo-2004', 'Arroyo-2005', 
for i, c in enumerate(presidents):
    with open("transcripts/" + c + ".txt", "rb") as file:
        data[c] = pickle.load(file)

# %%
# Double check to make sure data has been loaded properly
data.keys()
# Out:
# dict_keys(['Estrada-1998', 'Estrada-2000', 'Arroyo-2001', 'Arroyo-2002', 'Arroyo-2003', 'Arroyo-2004', 'Arroyo-2005', 'Arroyo-2006', 'Arroyo-2007', 'Arroyo-2008', 'Arroyo-2009', 'Aquino-2012', 'Aquino-2013', 'Aquino-2014', 'Aquino-2015', 'Duterte-2016', 'Duterte-2017', 'Duterte-2018', 'Duterte-2019', 'Duterte-2020', 'Duterte-2021'])

# %%
# More checks
data['Estrada-1998'][:7]
# Out:
# ['[youtube]http://www.youtube.com/watch?v=ZyrjG25Xpyo&feature=relmfu[/youtube] FULL TRANSCRIPT:',
#  'State of the Nation Address of His Excellency Joseph Ejercito Estrada President of the Philippines To the Congress Session Hall of the House of Representatives',
#  '[Delivered at Batasang Pambansa, Quezon City, on July 27, 1998]',
#  'Ang Pangalawang Pangulo ng Republika ng Pilipinas. Kagalang-galang na Pangulo ng Senado. Kagalang-galang na Speaker ng Mababang Kapulungan. Kagalang-galang na Punong Hukom ng Korte Suprema. Kagalang-galang na mga miyembro ng Kongreso ng Pilipinas. Kagalang-galang na mga kagawad ng mga Gabinete. Their excellencies of the diplomatic corps. Mga piling panauhin. Mga minamahal kong mga kababayan:',
#  'Noong Mayo onse, mahigit na 10 milyong Pilipino ang nagdesisyon na pamunuan natin ang bansa, patungo sa bagong milenyo.',
#  'Ngayon, sila ang nagtatanong, ano ba ang gagawin ng bagong pamunuang ito upang ihatid ang ating bansa sa bagong siglo?',
#  'Today, I stand before you with an accounting of the present and with a road map for our future.']

# %%
#Data Cleaning part

# %%
# Let's take a look at our data again
next(iter(data.keys()))
# Out:
# 'Estrada-1998'

# %%
# We are going to change this to key: president, value: string format
def combine_text(list_of_text):
    '''Takes a list of text and combines them into one large chunk of text.'''
    combined_text = ' '.join(list_of_text)
    return combined_text

# %%
# Combine it!
data_combined = {key: [combine_text(value)] for (key, value) in data.items()}

# %%
# We can either keep it in dictionary format or put it into a pandas dataframe
import pandas as pd
pd.set_option('max_colwidth',150)

data_df = pd.DataFrame.from_dict(data_combined).transpose()
data_df.columns = ['transcript']
data_df
# Out:
#                                                                                                                                                          transcript
# Estrada-1998  [youtube]http://www.youtube.com/watch?v=ZyrjG25Xpyo&feature=relmfu[/youtube] FULL TRANSCRIPT: State of the Nation Address of His Excellency Joseph...
# Estrada-2000  [youtube]http://www.youtube.com/watch?v=lSpYmtNQxeA[/youtube] TRANSCRIPT: Third State of the Nation AddressofHis Excellency Joseph Ejercito Estrad...
# Arroyo-2001   First State of the Nation AddressBy Gloria Macapagal-Arroyo14th President of the PhilippinesOpening of the 1st Regular Session of the 12th Congres...
# Arroyo-2002   [youtube]http://www.youtube.com/watch?v=4bGUktCRI2A&feature=relmfu[/youtube] TRANSCRIPT: Second State of the Nation Address By Gloria Macapagal-Ar...
# Arroyo-2003   Third State of the Nation Address of Her Excellency Gloria Macapagal-Arroyo President of the Philippines During the Opening of the 3rd Regular Ses...
# %%
import re
import nltk
nltk.download('stopwords')
import string
import os.path
from nltk.corpus import stopwords

# Check if file exists
stopwords_tl_file = "stopwords-tl.txt"
if os.path.isfile(stopwords_tl_file):
    with open(stopwords_tl_file, "r", encoding="utf8") as f:
        stopwords_tl = set([word.strip() for word in f])
else:
    print(f"{stopwords_tl_file} not found, using empty set for Filipino stopwords")
    stopwords_tl = set()

stop_words = set(stopwords.words('english')).union(stopwords_tl)

def clean_text_round1(text):
    '''Make text lowercase, remove text in square brackets, remove punctuation (except for periods, commas, and exclamation points), remove words containing numbers, remove stopwords, and remove URLs.'''
    text = text.lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation.replace('.','').replace(',','').replace('!', '')), '', text)
    text = re.sub('\w*\d\w*', '', text)
    text = re.sub(r'http\S+', '', text)
    text = re.sub(':', '', text)
    text = ' '.join([word for word in text.split() if word not in stop_words])
    text = re.sub('\s+', ' ', text).strip()
    text = text.strip()
    return text
# Out:
# stopwords-tl.txt not found, using empty set for Filipino stopwords
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
# Let's take a look at the updated text
data_clean = pd.DataFrame(data_df.transcript.apply(clean_text_round1))
data_clean
# Out:
#                                                                                                                                                          transcript
# Estrada-1998  full transcript state nation address excellency joseph ejercito estrada president philippines congress session hall house representatives ang pang...
# Estrada-2000  transcript third state nation addressofhis excellency joseph ejercito estradato congress philippines “toward new beginnings” thank much. honorable...
# Arroyo-2001   first state nation addressby gloria president philippinesopening regular session congress excellency president ramos senate president drilon senat...
# Arroyo-2002   transcript second state nation address gloria macapagalarroyo president philippines opening regular session congress thank you, speaker jose de ve...
# Arroyo-2003   third state nation address excellency gloria macapagalarroyo president philippines opening regular session congress thank speaker de venecia. vice...
# Arroyo-2004   full transcript fourth state nation address excellency gloria macapagalarroyo president philippines opening regular session congress thank speaker...
# Arroyo-2005   full transcript fifth state nation address excellency gloria macapagalarroyo president philippines opening regular session congress thank you. tha...
# Arroyo-2006   sixth state nation address excellency gloria macapagalarroyo president philippines opening regular session congress thank you. thank you, speaker ...
# Arroyo-2007   full transcript seventh state nation address excellency gloria macapagalarroyo president philippines opening regular session congress thank you. t...
# Arroyo-2008   full transcript eighth state nation address excellency gloria macapagalarroyo president philippines opening regular session congress thank you, sp...
# Arroyo-2009   full transcript ninth state nation address excellency gloria macapagalarroyo president philippines opening regular session congress thank you. lad...
# Aquino-2012   state nation address excellency benigno s. aquino iii president philippines congress philippines senate president juan ponce enrile speaker felici...
# Aquino-2013   state nation address excellency benigno s. aquino iii president philippines congress philippines vice president jejomar binay senate president fra...
# Aquino-2014   state nation address excellency benigno s. aquino iii president philippines congress philippines vice president jejomar binay president fidel vald...
# Aquino-2015   state nation address excellency benigno s. aquino iii president philippines congress philippines thank you, everyone. please sit down. begin, woul...
# Duterte-2016  state nation address rodrigo roa duterte president philippines congress philippines session hall house representatives thank you. please allow lit...
# Duterte-2017  state nation address rodrigo roa duterte president philippines congress philippines session hall house representatives kindly sit down. thank cour...
# Duterte-2018  state nation address rodrigo roa duterte president philippines congress philippines kindly sit down. thank courtesy. senate president vicente sott...
# Duterte-2019  state nation address rodrigo roa duterte president philippines congress philippines thank you. kindly sit down. kumusta po kayo senate president v...
# Duterte-2020  state nation address rodrigo roa duterte president philippines congress philippines kindly… senate president vicente sotto iii honorable members s...
# Duterte-2021  state nation address rodrigo roa duterte president philippines congress philippines session hall house representatives kindly sit down. far beauti...

# %%
# Apply a second round of cleaning
def clean_text_round2(text):
    '''Get rid of some additional punctuation, non-sensical text, and tabs that were missed the first time around.'''
    text = re.sub('[‘’“”…]', '', text)
    text = re.sub('\n', '', text)
    text = text.replace('\t', '')
    text = re.sub('state of the nation address', '', text)
    text = re.sub('full transcript', '', text)
    text = re.sub('of his excellency', '', text)
    text = re.sub('ofhis excellency', '', text)
    text = re.sub('president of the philippines during the opening of the regular session of the congress', '', text)
    text = re.sub('during the opening', '', text)
    text = re.sub('of the regular session of the congress', '', text)
    text = re.sub('president of the philippinesto the congress of the philippines', '', text)
    text = re.sub('of her excellency', '', text)
    text = re.sub('president of the philippines', '', text)
    text = re.sub(':', '', text)
    return text

round2 = lambda x: clean_text_round2(x)

# %%
# Let's take a look at the updated text
data_clean = pd.DataFrame(data_clean.transcript.apply(clean_text_round2))
data_clean
# Out:
#                                                                                                                                                          transcript
# Estrada-1998   state nation address excellency joseph ejercito estrada president philippines congress session hall house representatives ang pangalawang pangulo...
# Estrada-2000  transcript third state nation address joseph ejercito estradato congress philippines toward new beginnings thank much. honorable vice president gl...
# Arroyo-2001   first state nation addressby gloria president philippinesopening regular session congress excellency president ramos senate president drilon senat...
# Arroyo-2002   transcript second state nation address gloria macapagalarroyo president philippines opening regular session congress thank you, speaker jose de ve...
# Arroyo-2003   third state nation address excellency gloria macapagalarroyo president philippines opening regular session congress thank speaker de venecia. vice...
# Arroyo-2004    fourth state nation address excellency gloria macapagalarroyo president philippines opening regular session congress thank speaker de venecia vic...
# Arroyo-2005    fifth state nation address excellency gloria macapagalarroyo president philippines opening regular session congress thank you. thank you, speaker...
# Arroyo-2006   sixth state nation address excellency gloria macapagalarroyo president philippines opening regular session congress thank you. thank you, speaker ...
# Arroyo-2007    seventh state nation address excellency gloria macapagalarroyo president philippines opening regular session congress thank you. thank much speak...
# Arroyo-2008    eighth state nation address excellency gloria macapagalarroyo president philippines opening regular session congress thank you, speaker nograles....
# Arroyo-2009    ninth state nation address excellency gloria macapagalarroyo president philippines opening regular session congress thank you. ladies gentlemen, ...
# Aquino-2012   state nation address excellency benigno s. aquino iii president philippines congress philippines senate president juan ponce enrile speaker felici...
# Aquino-2013   state nation address excellency benigno s. aquino iii president philippines congress philippines vice president jejomar binay senate president fra...
# Aquino-2014   state nation address excellency benigno s. aquino iii president philippines congress philippines vice president jejomar binay president fidel vald...
# Aquino-2015   state nation address excellency benigno s. aquino iii president philippines congress philippines thank you, everyone. please sit down. begin, woul...
# Duterte-2016  state nation address rodrigo roa duterte president philippines congress philippines session hall house representatives thank you. please allow lit...
# Duterte-2017  state nation address rodrigo roa duterte president philippines congress philippines session hall house representatives kindly sit down. thank cour...
# Duterte-2018  state nation address rodrigo roa duterte president philippines congress philippines kindly sit down. thank courtesy. senate president vicente sott...
# Duterte-2019  state nation address rodrigo roa duterte president philippines congress philippines thank you. kindly sit down. kumusta po kayo senate president v...
# Duterte-2020  state nation address rodrigo roa duterte president philippines congress philippines kindly senate president vicente sotto iii honorable members se...
# Duterte-2021  state nation address rodrigo roa duterte president philippines congress philippines session hall house representatives kindly sit down. far beauti...

# %% [markdown]
# # Organizing the Data

# %%
# Let's take a look at our cleaned dataframe
data_clean
# Out:
#                                                                                                                                                          transcript
# Estrada-1998   state nation address excellency joseph ejercito estrada president philippines congress session hall house representatives ang pangalawang pangulo...
# Estrada-2000  transcript third state nation address joseph ejercito estradato congress philippines toward new beginnings thank much. honorable vice president gl...
# Arroyo-2001   first state nation addressby gloria president philippinesopening regular session congress excellency president ramos senate president drilon senat...
# Arroyo-2002   transcript second state nation address gloria macapagalarroyo president philippines opening regular session congress thank you, speaker jose de ve...
# Arroyo-2003   third state nation address excellency gloria macapagalarroyo president philippines opening regular session congress thank speaker de venecia. vice...
# Arroyo-2004    fourth state nation address excellency gloria macapagalarroyo president philippines opening regular session congress thank speaker de venecia vic...
# Arroyo-2005    fifth state nation address excellency gloria macapagalarroyo president philippines opening regular session congress thank you. thank you, speaker...
# Arroyo-2006   sixth state nation address excellency gloria macapagalarroyo president philippines opening regular session congress thank you. thank you, speaker ...
# Arroyo-2007    seventh state nation address excellency gloria macapagalarroyo president philippines opening regular session congress thank you
o ang tiwala kong mas matimbang ang pinagsama nating talino, sipag, kakayahan. let us first make accounting present. true accounting perhaps long overdue. nitong unang bahagi ng , ang paglago ng gross domestic product ay katumbas lamang sa percent ng antas na naitala noong . nangalahati ang produksyon ng mga pabrika natin. pawang pagbabawas ng imbentaryo—at hindi ang paglikha ng mga produkto—ang ginawa ng mga industriya natin. sa kanilang pangangamba sa recession, lalo lamang pinalala ang problema. bumagsak ang ating produksyong pangagrikultura. bumaba nang percent ang ani ng palay, bumaba din nang percent ang ani ng mais. malimit nating tukuyin ang phenomenon ng el niño, subalit ang tunay na ugat ng suliranin ay ang pangkalahatang sektor ng agrikultura. halos doubledigit na ang ating inflation rate. napakataas ang interes na sinisingil ng mga bangko kaya naman hindi makautang ang marami nating negosyante. lalo namang hinigpitan ng mga bangko ang kanilang pagpapautang, kayat maraming kalakal ang nagsasara. dahil sa debalwasyon sa el niño, tuluytuloy ang pagbagsak ng ating piso. ito ay lubhang mabigat para sa ating mga kababayan natin na isang kahig, isang tuka ang kinagisnang pamumuhay. unemployment . percent still growing underemployment, percent also growing. . million filipinos need job. twice number wish real, fulltime job. maaaring sabihing ito ay maliit pa. subalit paano mo sasabihin sa pamilyang gutom na mas masama ang kalagayan ng ibang pamilya sa ibang bansa one lost job one hungry family, one cold statistic cannot agree. statistics claim number poor people gone past decade. wonder people believe statistics. wala sa akin ang mga statistics na iyan. poor poor—walang pera, walang pagkain, walang bubong, walang dignidad, lalunglalo na, walang pagasa. hindi lang iyan. yung mayaman ay higit pang yumaman, ang mahihirap lalong humirap. wish could say shall set job security fund soon. dont want add inventory unfunded laws bills amount billion worth promises never fulfilled. according statistics, past six years, philippine economy grew, richest percent got percent national income. poorest percent wala pang dalawang porsiyento. worse countryside, percent filipinos still work onethird wag ...

# %%
import nltk
>>> nltk.download('punkt')
sentences = []
for index, row in data_clean.iterrows():
    president_year = row['full_nameyears']
    label = row['label']
    transcript = row['transcript']
    transcript_sentences = nltk.sent_tokenize(transcript)
    for sentence in transcript_sentences:
        sentences.append([president_year, sentence, label])

sentences_df = pd.DataFrame(sentences, columns=['president_year', 'sentence', 'label'])
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
sentences_df.head(10)
# Out:
#   president_year  \
# 0   Estrada-1998
# 1   Estrada-1998
# 2   Estrada-1998
# 3   Estrada-1998
# 4   Estrada-1998
# 5   Estrada-1998
# 6   Estrada-1998
# 7   Estrada-1998
# 8   Estrada-1998
# 9   Estrada-1998
#
#                                                                                                                                                 sentence  \
# 0   state nation address excellency joseph ejercito estrada president philippines congress session hall house representatives ang pangalawang pangulo...
# 1                                                                                                                   kagalanggalang na pangulo ng senado.
# 2                                                                                                      kagalanggalang na speaker ng mababang kapulungan.
# 3                                                                                                       kagalanggalang na punong hukom ng korte suprema.
# 4                                                                                               kagalanggalang na mga miyembro ng kongreso ng pilipinas.
# 5                                                                                                         kagalanggalang na mga kagawad ng mga gabinete.
# 6                                                                                                                         excellencies diplomatic corps.
# 7                                                                                                                                   mga piling panauhin.
# 8  mga minamahal kong mga kababayan noong mayo onse, mahigit na milyong pilipino ang nagdesisyon na pamunuan natin ang bansa, patungo sa bagong milenyo.
# 9  ngayon, sila ang nagtatanong, ano ba ang gagawin ng bagong pamunuang ito upang ihatid ang ating bansa sa bagong siglo today, stand accounting pres...
#
#    label
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN

# %% [markdown]
# # chunking into sentences and saving it to csv

# %%
sentences_df.to_csv('datacleanlabel.csv', index=False)

# %%
import os

print(os.listdir())
# Out:
# ['.config', 'transcripts', 'datacleanlabel.csv', 'sample_data']

# %% [markdown]
# # textblob

# %%
from textblob import TextBlob

def get_sentiment(polarity):
    if polarity > 0.0:
        return 2
    elif polarity < 0.0:
        return 0
    else:
        return 1

        

sentences_df['polarity'] = sentences_df['sentence'].apply(lambda sentence: TextBlob(sentence).sentiment.polarity)
sentences_df['label'] = sentences_df['polarity'].apply(lambda polarity: get_sentiment(polarity))

# %%
print(sentences_df)
# Out:
#      president_year  \
# 0      Estrada-1998
# 1      Estrada-1998
# 2      Estrada-1998
# 3      Estrada-1998
# 4      Estrada-1998
# ...             ...
# 9090   Duterte-2021
# 9091   Duterte-2021
# 9092   Duterte-2021
# 9093   Duterte-2021
# 9094   Duterte-2021
#
#                                                                                                                                                    sentence  \
# 0      state nation address excellency joseph ejercito estrada president philippines congress session hall house representatives ang pangalawang pangulo...
# 1                                                                                                                      kagalanggalang na pangulo ng senado.
# 2                                                                                                         kagalanggalang na speaker ng mababang kapulungan.
# 3                                                                                                          kagalanggalang na punong hukom ng korte suprema.
# 4                                                                                                  kagalanggalang na mga miyembro ng kongreso ng pilipinas.
# ...                                                                                                                                                     ...
# 9090                                                                                                             puno ang pila nito pagdating sa cr mamaya.
# 9091                                                                                                     full confidence filipino spirit persevere triumph.
# 9092                                                                                                                          together, let us rise nation.
# 9093                                                                                                                                             thank you.
# 9094                                                                                                                                                — end —
#
#       label  polarity
# 0         1      0.00
# 1         1      0.00
# 2         1      0.00
# 3         1      0.00
# 4         1      0.00
# ...     ...       ...
# 9090      1      0.00
# 9091      2      0.35
# 9092      1      0.00
# 9093      1      0.00
# 9094      1      0.00
#
# [9095 rows x 4 columns]

# %%
sentences_df.to_csv('sentences_with_polarity.csv', index=False)

# %% [markdown]
# # bert

# %% [markdown]
# # New Section

# %%
# !pip install transformers
from transformers import AutoTokenizer
import torch
import pandas as pd

# Replace 'bert-base-uncased' with the name of the pretrained model you want to use
tokenizer = AutoTokenizer.from_pretrained('bert-base-uncased')

# Load the data
df = pd.read_csv('sentences_with_polarity.csv')

# Preprocess the data
sentences = df['sentence'].tolist()

# Encode the data using BERT
input_ids = []
attention_masks = []
labels = []

for i in range(len(sentences)):
    sent = sentences[i]
    label = df['label'][i]
    if label not in [0, 1, 2]:
        continue
    encoded_dict = tokenizer.encode_plus(
                        sent,                      # Sentence to encode.
                        add_special_tokens = True, # Add '[CLS]' and '[SEP]'
                        max_length = 64,           # Pad & truncate all sentences.
                        truncation = True,
                        pad_to_max_length = True,
                        return_attention_mask = True,   # Construct attn. masks.
                        return_tensors = 'pt',     # Return pytorch tensors.
                   )
    
    # Check that the encoded_dict is not empty
    if encoded_dict:
        # Add the encoded sentence, its attention mask, and its label to the lists.    
        input_ids.append(encoded_dict['input_ids'])
        attention_masks.append(encoded_dict['attention_mask'])
        labels.append(label)

# Check that the labels list is not empty before converting it to a tensor
if labels:
    # Convert the data to tensors
    input_ids = torch.cat(input_ids, dim=0)
    attention_masks = torch.cat(attention_masks, dim=0)
    labels = torch.tensor(labels)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.27.4-py3-none-any.whl (6.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 70.8 MB/s eta 0:00:00
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 88.2 MB/s eta 0:00:00
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.9/dist-packages (from transformers) (4.65.0)
# Collecting huggingface-hub<1.0,>=0.11.0
#   Downloading huggingface_hub-0.13.3-py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.8/199.8 KB 21.3 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from transformers) (23.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from transformers) (2.27.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers) (3.10.7)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2.0.12)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.13.3 tokenizers-0.13.2 transformers-4.27.4
# Downloading (…)okenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# /usr/local/lib/python3.9/dist-packages/transformers/tokenization_utils_base.py:2346: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(

# %%
from torch.utils.data import TensorDataset, random_split

# Combine the input IDs and attention masks into a TensorDataset
dataset = TensorDataset(input_ids, attention_masks, labels)

# Define the dataset sizes for training, validation, and testing
train_size = int(0.8 * len(dataset))
val_size = int(0.1 * len(dataset))
test_size = len(dataset) - train_size - val_size

# Split the dataset into training, validation, and testing sets
train_dataset, val_dataset, test_dataset = random_split(dataset, [train_size, val_size, test_size])

# %%
from torch.utils.data import DataLoader, RandomSampler, SequentialSampler

# Define the batch size for training and validation
batch_size = 32

# Create the DataLoaders for the training, validation, and testing sets
train_dataloader = DataLoader(
            train_dataset,  
            sampler = RandomSampler(train_dataset), # Randomly sample the training data
            batch_size = batch_size 
        )

validation_dataloader = DataLoader(
            val_dataset,
            sampler = SequentialSampler(val_dataset), # Sequentially sample the validation data
            batch_size = batch_size 
        )

test_dataloader = DataLoader(
            test_dataset, 
            sampler = SequentialSampler(test_dataset), # Sequentially sample the test data
            batch_size = batch_size
        )

# %%
# Check if GPU is available
if torch.cuda.is_available():
    # If there is a GPU available, tell PyTorch to use the GPU
    device = torch.device("cuda")
    print('There are %d GPU(s) available.' % torch.cuda.device_count())
    print('We will use the GPU:', torch.cuda.get_device_name(0))
else:
    # If there is not a GPU available, tell PyTorch to use the CPU
    device = torch.device("cpu")
    print('No GPU available, using the CPU instead.')
# Out:
# No GPU available, using the CPU instead.

# %%
from transformers import BertForSequenceClassification
from transformers import AdamW, get_linear_schedule_with_warmup

num_epochs = 4
num_warmup_steps = int(len(train_dataloader) * 0.1)
num_training_steps = len(train_dataloader) * num_epochs

# Define the model
model = BertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=3)

# Define the optimizer and learning rate
optimizer = AdamW(model.parameters(), lr=2e-5, eps=1e-8)

# Create the learning rate scheduler
scheduler = get_linear_schedule_with_warmup(optimizer, 
                                            num_warmup_steps=num_warmup_steps,
                                            num_training_steps=num_training_steps)
# Out:
# Downloading pytorch_model.bin:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.9/dist-packages/transformers/optimization.py:391: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(

# %%
from transformers import get_linear_schedule_with_warmup
from transformers import AdamW
import torch.nn as nn

# Define the loss function
cross_entropy_loss = nn.CrossEntropyLoss()

# Define the number of training epochs
epochs = 3

# Define the optimizer and learning rate
optimizer = AdamW(model.parameters(), lr=2e-5, eps=1e-8)

# Create the learning rate scheduler
scheduler = get_linear_schedule_with_warmup(optimizer, 
                                            num_warmup_steps = 0,
                                            num_training_steps = len(train_dataloader) * epochs)

# Define the evaluation function
def evaluate(dataloader):
    # Put the model in evaluation mode
    model.eval()

    # Define variables to store metrics
    eval_loss, eval_accuracy = 0, 0
    nb_eval_steps, nb_eval_examples = 0, 0

    # Loop through each batch in the dataloader
    for batch in dataloader:
        # Unpack the batch
        input_ids_batch, attention_masks_batch, labels_batch = batch

        # Move the batch to the GPU
        input_ids_batch = input_ids_batch.to(device)
        attention_masks_batch = attention_masks_batch.to(device)
        labels_batch = labels_batch.to(device)

        # Tell the model not to compute or store gradients
        with torch.no_grad():        
            # Forward pass, calculate logit predictions
            outputs = model(input_ids_batch, 
                            token_type_ids=None, 
                            attention_mask=attention_masks_batch)

        # Get the predicted labels
        logits = outputs[0]
        pred_labels = torch.argmax(logits, dim=1)

        # Calculate the accuracy and loss
        tmp_eval_accuracy = accuracy(logits, labels_batch)
        eval_accuracy += tmp_eval_accuracy
        eval_loss += cross_entropy_loss(logits, labels_batch)

        nb_eval_examples += input_ids_batch.size(0)
        nb_eval_steps += 1

    # Calculate the average accuracy and loss
    eval_accuracy = eval_accuracy / nb_eval_examples
    eval_loss = eval_loss / nb_eval_steps

    return eval_loss, eval_accuracy

# Train the model
for epoch in range(epochs):
    # Put the model in training mode
    model.train()
    train_loss = 0

    # Loop through each batch in the training dataloader
    for batch in train_dataloader:
        # Unpack the batch
        input_ids_batch, attention_masks_batch, labels_batch = batch

        # Move the batch to the GPU
        input_ids_batch = input_ids_batch.to(device)
        attention_masks_batch = attention_masks_batch.to(device)
        labels_batch = labels_batch.to(device)

        # Clear out any previously calculated gradients
        optimizer.zero_grad()

        # Forward pass, calculate logit predictions
        outputs = model(input_ids_batch, 
                        token_type_ids=None, 
                        attention_mask=attention_masks_batch)

        # Calculate the loss
        loss = cross_entropy_loss(outputs[0], labels_batch)
        train_loss += loss.item()

        # Backward pass, calculate gradients
        loss.backward()

        # Clip the norm of the gradients to 1.0 to prevent exploding gradients
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)

        # Update the parameters and the learning rate
        optimizer.step()
        scheduler.step()

    # Evaluate the model on the validation set
    val_loss, val_accuracy = evaluate(validation_dataloader)

    # Print the loss and accuracy for the current epoch
    print("Epoch {}/{}".format(epoch+1, epochs))
    print("Training Loss: {:.3f}".format(train_loss/len(train_dataloader)))
    print("Validation Loss: {:.3f}".format(val_loss))
    print("Validation Accuracy: {:.3f}".format(val_accuracy))
